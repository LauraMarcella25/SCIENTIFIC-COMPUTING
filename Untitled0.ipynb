# %% [markdown]
# <a href="https://colab.research.google.com/github/LauraMarcella25/SCIENTIFIC-COMPUTING/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-poster')
# %matplotlib inline

#define parameters
f=lambda t, s:np.exp(-t) #ODE
h=0.1 #step size
t=np.arange(0, 1+h, h) #numerical grid
s0=-1 #initial condition

#explicit eular method
s=np.zeros(len(t))
s[0]=s0

for i in range (0, len(t) - 1):
  s[i+1]=s[i]+h*f(t[i], s[i])

plt.figure(figsize=(12, 8))
plt.plot(t, s, 'bo--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \ for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
h=0.01 #step size
t=np.arange(0, 1+h, h) #Numerical grid
s0=-1 #initial condition

#explicit euler method
s=np.zeros(len(t))
s[0]=s0

for i in range(0, len(t)-1):
  s[i+1]=s[i]+h*f(t[i], s[i])

plt.figure(figsize=(12, 8))
plt.plot(t, s, 'b--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
f = lambda t, y: -4 * y

h = 0.1
t = np.arange(0, 1 + h, h)
y = np.zeros(len(t))
y[0] = 1

for i in range(len(t) - 1):
    y[i + 1] = y[i] + h * f(t[i], y[i])

y_exact = np.exp(-4 * t)

plt.figure(figsize=(10, 6))
plt.plot(t, y, 'b--o', label='Approximate')
plt.plot(t, y_exact, 'g', label='Exact')
plt.title('Approximate and Exact Solution for dy/dt = -4y')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.grid(True)
plt.legend(loc='lower right')
plt.show()
